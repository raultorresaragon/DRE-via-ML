# %% [markdown]
# # My First Jupyter Notebook
#
# This is a simple example notebook.

# %%
# Simple Python code
print("Hello, Jupyter!")

# Basic math
x = 15
y = 20
result = x + y
print(f"The sum of {x} and {y} is {result}")
# Out:
# Hello, Jupyter!
# The sum of 15 and 20 is 35

# %%
# Create a simple list and loop
fruits = ['apple', 'banana', 'orange']

for fruit in fruits:
    print(f"I like {fruit}")
# Out:
# I like apple
# I like banana
# I like orange

# %% [markdown]
# ## That's it!
#
# You can now run each cell by clicking the play button or pressing Shift+Enter.
